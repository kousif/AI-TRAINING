# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.quiver(0,0,3,4)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.quiver(0,0,3,4,scale_units='xy',angles='xy',scale=1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.quiver(0,0,3,4,scale_units='xy',angles='xy',scale=1)
plt.xlim(-10,10)
plt.ylim(-10,10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.quiver(0,0,3,4,scale_units='xy',angles='xy',scale=1)
plt.quiver(0,0,-3,-4,scale_units='xy',angles='xy',scale=1)

plt.xlim(-10,10)
plt.ylim(-10,10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.quiver(0,0,3,4,scale_units='xy',angles='xy',scale=1)
plt.quiver(0,0,-3,4,scale_units='xy',angles='xy',scale=1)

plt.xlim(-10,10)
plt.ylim(-10,10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.quiver(0,0,3,4,scale_units='xy',angles='xy',scale=1,color='r')
plt.quiver(0,0,-3,4,scale_units='xy',angles='xy',scale=1,color='g')

plt.xlim(-10,10)
plt.ylim(-10,10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt

def plot_vectors(vecs):
    colors = ['r', 'b', 'g', 'y']
    i = 0
    for vec in vecs:
        plt.quiver(vec[0], vec[1], vec[2], vec[3],
                   scale_units='xy', angles='xy', scale=1,
                   color=colors[i % len(colors)])
        i += 1

    plt.xlim(-10, 10)
    plt.ylim(-10, 10)
    plt.grid(True)
    plt.show()

# Example usage
plot_vectors([(0, 0, 3, 4), (0, 0, -3, 4),(0,0,-3,-2),(0,0,4,-1)])

# %%
import numpy as np
vecs =[np.asarray([0,0,3,4]),np.asarray([0,0,-3,4]),np.asarray([0,0,-3,-2]),np.asarray([0,0,-4,-1])]

# %%
plot_vectors([vecs[3],vecs[1]])

# %%
vecs[0]+vecs[3]
# Out:
# array([ 0,  0, -1,  3])

# %%
plot_vectors([vecs[0],vecs[2],vecs[0]+vecs[2]])

# %%
plot_vectors([vecs[1],vecs[3],vecs[1]+vecs[3]])

# %%
plot_vectors([vecs[0],vecs[1],vecs[0]+vecs[1]])

# %%
plot_vectors([vecs[1],vecs[1],vecs[1]+vecs[1]])

# %%
plot_vectors([vecs[0],vecs[1],vecs[0]-vecs[1]])

# %%
plot_vectors([vecs[1],vecs[3],vecs[1]-vecs[3]])

# %%
plot_vectors([-vecs[0],vecs[1],-vecs[0]+vecs[1]])

# %%
vecs =[np.asarray([0,0,3,4]),np.asarray([0,0,-3,4]),np.asarray([0,0,-3,-2]),np.asarray([0,0,-4,-1])]

# %%
plot_vectors(vecs)

# %%
a=np.asarray([3,4])
b=np.asarray([4,-1])

# %%
dot_product = np.dot(a, b)
magnitude_a = np.linalg.norm(a)
magnitude_b = np.linalg.norm(b)
cos_theta = dot_product / (magnitude_a * magnitude_b)

print(f"Dot product: {dot_product}")
print(f"|a|: {magnitude_a}")
print(f"|b|: {magnitude_b}")
print(f"cos(theta): {cos_theta}")
# Out:
# Dot product: 8
# |a|: 5.0
# |b|: 4.123105625617661
# cos(theta): 0.38805700005813276

# %%
a_dot_b = np.dot(a, b)

# %%
print(a_dot_b)
# Out:
# 8

# %%
a_b = magnitude_a * cos_theta
print(f"a_b = {a_b}")
# Out:
# a_b = 1.9402850002906638

# %%
a_b = np.dot(a,b)/np.linalg.norm(b)

# %%
print(a_b)
# Out:
# 1.9402850002906638

# %%
a_b_vec = a_b * (b / magnitude_b)
print("a_b_vec =", a_b_vec)
# Out:
# a_b_vec = [ 1.88235294 -0.47058824]

# %%
vec_a_b=(a_b/np.linalg.norm(b))*b

# %%
plot_vectors([np.asarray([0,0,3,4]),np.asarray([0,0,4,-1])]),np.asarray([0,0,1.88235294 -0.47058824])
# Out:
# (None, array([0.       , 0.       , 1.4117647]))
